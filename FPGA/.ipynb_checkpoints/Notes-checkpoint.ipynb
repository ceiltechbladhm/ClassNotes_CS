# %% [markdown]
# # Code

# %%
# %%javascript
#
#     var add_command_shortcuts = {
#             'Alt-w' : {
#                 help    : 'Add Text Test',
#                 help_index : 'aa',
#                 handler : function() {
#                         var cell = IPython.notebook.get_selected_cell();
#         		cell.code_mirror.replaceSelection('Testing');
#                 }
#             }
#         };
#
#     var add_edit_shortcuts = {
#             'Alt-a' : {
#                 help    : 'Insert alpha',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\alpha');
#                 }
#             },
#         'Alt-b' : {
#                 help    : 'Insert beta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\beta');
#                 }
#             },
#         'Alt-g' : {
#                 help    : 'Insert gamma',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\gamma');
#                 }
#             },
#         'Alt-shift-g' : {
#                 help    : 'Insert Gamma',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\Gamma');
#                 }
#             },
#         'Alt-Ctrl-d' : { //Change
#                 help    : 'Insert delta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\delta');
#                 }
#             },
#         'Alt-Ctrl-e' : {
#                 help    : 'Insert epsilon',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\epsilon');
#                 }
#             },
#         'Alt-z' : {
#                 help    : 'Insert zeta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\zeta');
#                 }
#             },
#         'Alt-t' : {
#                 help    : 'Insert theta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\theta');
#                 }
#             },
#         'Alt-k' : {
#                 help    : 'Insert kappa',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\kappa');
#                 }
#             },
#         'Alt-l' : {
#                 help    : 'Insert lambda',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\lambda');
#                 }
#             },
#         'Alt-p' : {
#                 help    : 'Insert phi',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\phi');
#                 }
#             },
#         'Alt-r' : {
#                 help    : 'Insert rho',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\rho');
#                 }
#             },
#         'Alt-s' : {
#                 help    : 'Insert sigma',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\sigma');
#                 }
#             },
#         'Alt-w' : {
#                 help    : 'Insert omega',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\omega');
#                 }
#             },
#         'Ctrl-Alt-1' : {
#                 help    : 'Insert dfrac',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\dfrac{}{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-3});
#                 }
#             },
#         'Ctrl-Alt-7' : {
#                 help    : 'Insert integral',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\int_{}^{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-4});
#                 }
#             },
#         'Ctrl-Alt-3' : {
#                 help    : 'Insert cos',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\text{cos}');
#                 }
#             },
#         'Ctrl-Alt-4' : {
#                 help    : 'Insert sin',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\text{sin}');
#                 }
#             },
#         'Ctrl-Alt-5' : {
#                 help    : 'Insert Brackets',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\left[  \\right]');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-8});
#                 }
#             },
#         'Ctrl-Alt-6' : {
#                 help    : 'Insert parenthesis',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\left(  \\right)');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-8});
#                 }
#             },
#         'Ctrl-Alt-7' : {
#                 help    : 'Insert parenthesis',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\left[\\begin{matrix}  \\end{matrix}\\right]');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-20});
#                 }
#             },
#         'Ctrl-Alt-2' : {
#                 help    : 'Insert equation',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('$$  $$');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-3});
#                 }
#             },
#         'Alt-0' : {
#                 help    : 'Insert partial',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\partial ');
#                 }
#             },
#         'Ctrl-Alt-n' : {
#                 help    : 'Insert nabla',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\nabla');
#                 }
#             },
#         'Alt-Shift-t' : {
#                 help    : 'Insert text',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\text{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
# /*        'Shift-6' : {
#                 help    : 'Insert superscript',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('^{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
#         'Shift-_' : {
#                 help    : 'Insert subscript',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('_{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
# */
#         };
#
#    // var load_ipython_extension = function() {
#         IPython.keyboard_manager.edit_shortcuts.add_shortcuts(add_edit_shortcuts);
#         IPython.keyboard_manager.command_shortcuts.add_shortcuts(add_command_shortcuts);
#     //};

# %% [markdown]
# # Lecture 2

# %% [markdown]
# Look at the Stratix, II, and 10 papers.
#
# ALM/CLB - basically collection of LUTs and bits. Have registers, and chains, The outputs could come directly out of LUTs. They also allow you to directly tap into the register. Local interconnect (intra-CLB connections). Internally, they also have some feedback paths from the outputs. This will be very fast and cheap.
#
# Some level of flexibility from routing and the CLB. Same is true of the output. In general terms, this is called connection box. Connection box flexibility says what percentave from the innerconnect can make connections to the local logic. Full connectivity means any wire can connect to any of the inputs. Full flexibility means no constraints on tools downstream. Also lots and lots of switches (6 sram switches each).
#
# Other is called the switch box (SB). The tracks make up the large portion of area used. SB has its own flexibility.
#
# Fracturable LUTs. Altera used efficiently.
#
# inputs have some delay for LUTs. Potentially optimize the bit which changes most often by using the input with the least delay.
#
# Another approach; output is gotten from logic, clock stopped, LUTs updated, clock started again.
#
# If we look at older architectures, they used 4-LUT.
#
# Rent rule - as the designs get bigger, fewer wires go between half of the design.
#
# We are using flip flops; why no logic connected to it? Buffer signal, shift register.
#
# Adders are put in for fast addition. possible to do fast 12 bit adder. Generally we will use 1:1 ratio for registers and LUTs.
#
# Has a ram of 8 entries of 1 bit. 1 port ram, any bit of time, one address, one value. Two port, two addreses, two pieces of data.
#
# 2 1/2 D tech. Like 3D but not. They broke up the FPGA into 4 smaller chunks. There is a large bin, a large piece of silicon. There is interconnect which made connections between the chunks.
#
# The important parto f flow map:privided first part of depth (delay); showed you could optimize depth. Also want to minimize area. Instead, came upwith "hacks".
#
# K-feasible cone at v - refers to predacessor of a gate. If we have an AND gate whose inputs are connected to OR gate and XOR gate, the cone refers to all inputs connected to the AND.
#
# Level of a node; traversal of a circuit. They go from top (inputs) and go level by level.

# %% [markdown]
# # Lecture 3

# %% [markdown]
# Forget about the logic; as long as you can have 3 inputs into a box, that's all we need to know. This is crucial. The other two big ideas are: I can optimally find the minimum depth of logic. I can guranteee minimum depth implementation. Minimum depth doesn't mean minimum area. Then they propose heuristics. This refers to something hit-or-miss. No gurantee of optimization. They have a lot of techniques which make sense. Unlike depth minimization, which looks at the entire thing. This can gurantee.
#
# Directed acyclic graph. Always go from inputs to outputs, no feedback. If we have a circuitwith a lot of inputs, they go into gates and flip flops and other gates, usually we treat a flipflop as an output pin and input pin. Treats outputs as "virtual inputs" when they are used as feedbacks.
#
# K-feasible cone. This cone could have hundreds of gates inside. The boolean network itself is k-bounded. Any gate we pick, the gate itself doesn't have any more than K inputs. An AND gate which has 5 inputs, for example, can break it into a 3 input AND gate, 2 input AND gate, whose outputs are fed into a 2 input AND gate.
#
# Once we have this constraint on the network, we have a solution. A mapping from logic gate to FPGA. WEe can replace every gate with a LUT (really inneffecient, but possible).
#
# We have to make assumptions. Break down problems into smaller chunks. There have been papers recently. They use flow map to provide these gates. They feed the clustering of gates into a placement tool. Looks for really long wires (long delays), then goes back to flow map and reiterates another design. Notion of cut-size.
#
# There is a famous problem in graph algorithms that says if we have a bunch of nodes in a graph and connections between them, if we take a slice across it (known as a cut), we ask what is the capacity of the road across it.
#
# If the characteristic of something is monotonic, useful for experts in a field, look for basic properties of these. If this is monotonically increasing, and we have a k-feasible cut, further along, this property isn't necessarily preserved. The insight was to map it to the network flow problem. Two phases. The labeling phase: at any point in time, I am concerned with only one gate. I don't care what happens to anything else. Theinputs come to a gate, what is the best depth you can make. The best I can do is with so many gates.
#
# Topological order. This says that, if I have a DAG, I can visit these gates one after the other. Let's say I want to find the longest path in the network, longest delay. I could have a network which has many connections. HOw do we find the longest path without enumerating every single paths? If we have N gates in the circuit, we could have $2^N$ paths.  If we come up with any algorithm which needs every single path, the order of complexity is doomed.
#
# When we want to process anode, the depth is either a maximum node from the predecessor. Is is possible to cut and use predecessors with a value of 1? Label 2 means I don't care about other nodes, best I can do is 2. Once we decide about a label for a node.
#
# t' depth could be one is fe could path every gate into 1. the predecessor have a depth of 2. t' now a collapsed version of all of the 2s. Can we find a cut of t' which encompasses the 1s?
#
# Network flow only works on edges. Electrically, however, we care about nodes (two lines can come from the same node; this is electrically equivelant, normal graph throy can't comprehend this). If the network flow says yes, which is less than or equal to K, we can collapse t and have 1 look up table represent them. If not, we can't use a simplified cut. We made restriction of original network that gatescan only have so many inputs.
#
# Your problem statement is slightly different from classic minimum cut algorithm. We onl ycare about cut below 3 (don't care if actual minimum is 2 or 1). We can now add in a way to care about area for example.
#
# Phase 2: trace back from outputs to inputs, decide which cuts to use. When tracing back, the dotted lines become important too. We choose t to be output of LUT. pack
#
# Carry chains. Large inputs. Memory, DSP blocks which do multiply, accumulate. Statics or Statics II, had 9 bit multiplication, group to 18 or 36 bit. Lots of customers wanted this. Do we provide cross-bar connections between modules. Bunch of academic papers published. Another thing is floating point operations.
#
# As a user, if we use an FPGA, the routing may take 20 hours. If we give it 20, may take 4 hours. If we have enough wires, it has enough flexibility. Routing stress refers to the time it takes to route.
#
# A staggered wire/routing. The previous version of Altera (flexed series) had heirarchical way of routing these things. Would connect using single ones. Had double lines. Multidimensional thing; Try to pack things together, but when necessary, use lines to bypass other neighbors.
#
# Abandoned the pass-baed transistor. Went with mux instead. WE see that each of the pass transistors happened with connections. Pass transistor weakens the signal. Moved away. The problem with mux is that the area is larger. Comprimise and use both. Delays can be assigned critical values; more important ones can use mux, not so important ones use pass transistors.
#
# Whenw e use the dierect driver, the critical pathe driver is not sensitive to channel width. Routing stress becomes less of an issue.
#
# VPR, TVPR, also Harp paper: read for next week. We'll post if he remembers something else.

# %% [markdown]
# # Lecture

# %% [markdown]
# ###### Posted some papers which have some ofthe architecture changes. The research that Xilinx and altera did.
#
# Question: in same paragraph, current architecture does now allow span more than 1 logic block.
#
# Remmeber that the routing segments. The routing segments goe from switchbox to switch box. The routing segment skips switch boxes. They fixed it. The default architecture has a something of 4.
#
# Question: include 8 LUTs t? New version does fracturable LUTs. Heirarchical doesn't go anywhwere. Heirarchitecural started, but converged with altera. The effectof placing A and B fartehr from each other, takes more routing materials. Need measure to tell how many routing resources we are using. Are we going to create a lot of congestion in a particular area? Want overall number routing number  to being low, but also want to avoid local congestion. At VPR level, these are the same problems.
#
# In timberwolf and other asic version, calculate wiring cost, look at euclidian distance. Not a good measure, doen'st tell how many vertical and horizontal connections are used. In VPR, we look at bounding box thich uses all the pins. Can have multiple pins (goes fromA to B , C ,maybe D), looking at routing tree. We could look at perimieter of box. Could be an optimistic approach (multiple lines along a segment within rectangle), but works pretty good nonetheless.
#
# Begin with random placement.
#
# Do detailed routing, helps. Progressinvely more detailed. We can't handle the amount of infomratino to do it anothe way, even though this isn't ideal. Stochastic optimization process. We don't know any better. Looks at how crystals form in nature. Cools down gradually, brak off, see cystals. Have state of energy in atoms. Say two atoms of iron collide.
#
# Escaping a local optimum. As we cool things down, we reject more and more bad moves. Called annealing. Doesn't gurantee optimality. Cal run it multiple times. If we hae a problem with which a small change cuases small
#
# We set initial temperature, then set coolilng schedule. If acceptance rate is less than that, change again. Have freezing temparature. Say temp is 33500, have set number of moves to try. VPR uses a different constant.  The simulated annealing algorithm. Perturbed procedure. Pick 2 cells reandomly and swap them. Don't have to have just 1 move. Could be take just one cell, move randomly to new location. or could overlap. Deduct from the cost. The point is that we could have aset of 3-4 moves. Now we can evaluate the cost of this. We could subtract them. Always accepta good move. If it isn't, make a probability call. If a number is lower than a randomly generated number, then accept the move; otherwise reject. Gradually shrink the size of the box where cells can be swapped.
#
# Diijkstra algorithm. Finds shortest path in a network. Starts with seed, branches out
#
# Lets assume location 1 is at 0,0. Look at somewhere x,y. What is delay between points. Routing is not symmetric. (only have access from, say, 2 sides). What they say, look at chip in isolation. Run pathfinder algorithm. Finds fastest route. Builds a 2D table which has a delay. Because FPGA is homogeneous, it doesn't matter where the origin is et. Gives an architecture. They pick these number s to determine the bounding box. Now have delay value. INstead of having A which feeds DC and B, now add up delay between A and the other 3 nodes. The max delay we would have would be considered, and that would be the delay cost. Is this an upper/lower bound? Relation to final solution?
#
# usually ahve a comvination of delay and wire length. Important notion is slack. Not all wires are the same. Reset, for example, not time critical. Not trying to pack that in. Multiply each by how critical the timing is. Delay cost is
#
# We calculate an arrival time. Depth of this is 2. Tells you that the clock can't be shorter than x (clock time). May not actually be achievable. IN reality, it will be longer (delay in wire as well). The difference for each node, is the slack. The difference between arrivatl time and required time gives the slack. 1/slack tells how critical things are. Fidelity is an important term, especially in optimization. The placement method of routing cost.
#
# Placement and after routing. Placement says clock freq 200 MHz. After routing, clock has 170 MHz. Or say, 150 MHz initally and after routing, we have 120. If we look at the correlation between these two numbers (of course placement isn't accurate), but at least there is positive correlation. There is good fideliy (how much positive correlation there is between these two numbers0. If the placmenet is looking at two solutions, makes random move and becomes better, we accept it.

# %% [markdown]
# # Lecture

# %% [markdown]
# Stratix 10 paper. Asic costs are increasing. People wanted to have aplatform, fabricate once, then many customers use it. Problem: FPGAs are slow. 10x difference between Asic and FPGA. Originally, fpga fast as 100-200 MHz. Via programmable devices; 2D chip has bunch of devices. Things similar to switch boxes. The programming for these is not baes on SRAM (which add extra area and switch box).
#
# Layers 1-3 - Power ground clock reset
# Layers 4-5
# Layer 6 - unfinished.
#
# Customer has custom needs. A mask is created for layers 6-7. Making connection with metals. Called VPGA. Called structured ASIC solutions. Similar philosophy. ASIC units. People have high opes for packaging it, leaving some switches. Over the years, more was added. In general, making masks is expensive. If we have 6-7 metal layers, overall have 20 masked sets.
#
# Lets see what patterns ar actually used. Look at the data.
#
# If we use a different routing algorithm. Not very sensitive to routing algorithm. Towards boundaries, expect to see more L's. Center more t's. Not actually the case. Why? Don't worry too much about geometric distribution. If we anted to chagne based onthe geomgetric location, hard to add connections.
#
# Length of segments. STudy leading you to choose length 6 wires, you expect this resource to use more, so put more money towards making that resource the best. Segment length 2 wires faster than length 1 b/c a larger buffer was used.
#
# VPR router works: each source and sink represented by node in graphy. Wire segments are represented as notdes. Add a delay to eac hwire. Crate graph showing possibliities. Run algorithm to tell what is fastest way to go. We take away roads from cities.
#
# Algorithm for inserting harp wires. Go row by row, randomly insert HARP.
#
# Integer linear programming (ILP). Take a course in this! :) Super important apparently.
#
# Retiming - say you are timing a clock period of 10 ns. Bunch of gates whic hgo from flip flop to flip flop. If it has a delay of 12 ns, it is violating the delay of the flip flop. If second path, however, only has a delay of 8ns, it is possible to move the flip flop back a gate, making both paths 10 ns long. Can aslo add artificial flip flop to lenghten time.
#
# Multiplication with a single and gate.

# %% [markdown]
# # Lecture

# %% [markdown]
# The designers used to go in and say, what is the critival paths (longest delay). Had to manually go in, see synthesis tool didn't do a good job. Manually pipeline the design. Pipline tool tool done automatically. Typical routing multiplexers. Have layout tool. Doing for application. Run through routing schemes and find the longest path? Used a routing mux. essentially a 16-to-1 mux. Broken down into two levels. One way the EE make pass transistors better, increase voltage on gate, channel resistance goes lower. Called the keeper. Bypass. Every singe input must go through gates.
#
# Balancing paths. May be some long paths which we want to retime. Must add flipflops to match delay from a longer path. Wire pipelining. What does this say. Loop limit. Direct feedback using gates and flip flop. For every one cycle, we execute one instruction.
#
# When you design your clock, in an ideal world, edges happen instantaneously. Realistically, there is some delay between the edges and the action which occurs. To solve this, a fractal clock is used; there is the same amount of distance between all access ports on the clock. Don't want to create a global one.
#
# High speed serial interface; parallel to serial or visa versa. Could be Gb/s speed.

# %% [markdown]
# # Lecture

# %% [markdown]
# Last 2 years of FPGA
#
# Stochastic computing and its applications. This has been going on for a long while. Goes back a long ways.
#
# Multiplication: in total, 30 gates needed.
#
# Represening a value of a sequence of random bits. if real value in [0,1] is represented by a sequenc of random bits, each has a probability of being 0 or 1. Here, position doesn't matter. Kind of like a pebble based system (a base 1 number system - order doesnt matter, if you have a 1, it can be switch to any other position). 01 = 10 base 1.
#
# If we generate two bit streams, a and b. a = 6/8 (11010111) and b = 4/8 (11001010). Using the and gate,
#
#
# Source of randomness. have pseudorandom number generators. linear shift feedback. every cycle, we shift the values one by one. LFSR -> take 2 LSB, XOR it, send to the front. Generate random numbers, compare with number you want. If less than, output 0. If greater than, output 1.

# %% [markdown]
# # Lecture

# %% [markdown]
# Looking at getting the zip code on an envelope. We want to extract features, be insensitive to an offset, tolerant of some rotation. We take the inputs, then we would decide on a topology (what kind of network we want to have). We come up with an architecture which translates them into vectors. This translates them into a smaller subsection.
#
# Kernels start forming which give you features.
#
# To reduce overfitting, at test time, avaerage the predictions on the 10 patches.
#
# Bernstein Polynomials
#
# The Bernstein basis polynomial of a degree n
#
# $$ B_{i,n}(t) = \left(\begin{matrix} n \\ i \end{matrix}\right)t^i(1-t)^{n-i} \text{, } i=0,...,n $$
#
# If we drop a ball down a pyramid of pegs (like plenko), and the ball has an equal probability of falling to either side. Once we have the distributions, let's say somehow we have all the distributions. A funciton which maps probabilities to probabilities. All  we need to do is to find a wight for each bin such that, when we multiply, we get a function that we desire.
#
# Each is the basis polynomial.

# %% [markdown]
# # Lecture

# %% [markdown]
# How many LUT into a CLB. what kind of routing flexibility within CLB? Have full cross-bar? These were the questions we were originally intereested in. Don't have to go down to the transistor level to answer.
#
# HWe can get some delay numbers. Want touse set of 10 Tables within CLB. Numbers wouldn't change much. COFFE transistor sizing tool. Once we have a bunch of transsitors which need to connected. They all need to go into some sort of bus.
#
# Claiming we can prediect with the layout.
#
# Level shifter is used. Memory, use higher voltage to make sure access is fast.
#
# If we look at a polynomial in the form  of:
# $$ y = -2x^2 - 2x $$
#
# This maps the range 0 to 1 to itself. Howe we will impelemnt this?
