# %% [markdown]
# # Code

# %%
# %%javascript
#
#     var add_command_shortcuts = {
#             'Alt-w' : {
#                 help    : 'Add Text Test',
#                 help_index : 'aa',
#                 handler : function() {
#                         var cell = IPython.notebook.get_selected_cell();
#         		cell.code_mirror.replaceSelection('Testing');
#                 }
#             }
#         };
#
#     var add_edit_shortcuts = {
#             'Alt-a' : {
#                 help    : 'Insert alpha',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\alpha');
#                 }
#             },
#         'Alt-b' : {
#                 help    : 'Insert beta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\beta');
#                 }
#             },
#         'Alt-g' : {
#                 help    : 'Insert gamma',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\gamma');
#                 }
#             },
#         'Alt-shift-g' : {
#                 help    : 'Insert Gamma',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\Gamma');
#                 }
#             },
#         'Alt-Ctrl-d' : { //Change
#                 help    : 'Insert delta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\delta');
#                 }
#             },
#         'Alt-Ctrl-e' : {
#                 help    : 'Insert epsilon',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\epsilon');
#                 }
#             },
#         'Alt-Ctrl-Shift-e' : {
#                 help    : 'Insert varepsilon',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\varepsilon');
#                 }
#             },
#         'Alt-z' : {
#                 help    : 'Insert zeta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\zeta');
#                 }
#             },
#         'Alt-t' : {
#                 help    : 'Insert theta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\theta');
#                 }
#             },
#         'Alt-k' : {
#                 help    : 'Insert kappa',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\kappa');
#                 }
#             },
#         'Alt-l' : {
#                 help    : 'Insert lambda',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\lambda');
#                 }
#             },
#         'Alt-p' : {
#                 help    : 'Insert prime',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\prime');
#                 }
#             },
#         'Alt-r' : {
#                 help    : 'Insert rho',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\rho');
#                 }
#             },
#         'Alt-s' : {
#                 help    : 'Insert sigma',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\sigma');
#                 }
#             },
#         'Alt-w' : {
#                 help    : 'Insert omega',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\omega');
#                 }
#             },
#         'Ctrl-Alt-1' : {
#                 help    : 'Insert dfrac',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\dfrac{}{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-3});
#                 }
#             },
#         'Ctrl-Alt-2' : {
#                 help    : 'Insert equation',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('$$  $$');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-3});
#                 }
#             },
#         'Ctrl-Alt-3' : {
#                 help    : 'Insert bar',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\bar{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
#         'Ctrl-Alt-4' : {
#                 help    : 'Insert hat',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\hat{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
#         'Ctrl-Alt-5' : {
#                 help    : 'Insert hat',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\tilde{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
#         'Ctrl-Alt-6' : {
#                 help    : 'Insert parenthesis',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\left(  \\right)');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-8});
#                 }
#             },
#         'Ctrl-Alt-7' : {
#                 help    : 'Insert Brackets',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\left[  \\right]');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-8});
#                 }
#             },
#         'Ctrl-Alt-8' : {
#                 help    : 'Insert angle',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\langle  \\rangle');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-8});
#                 }
#             },
#         'Ctrl-Alt-9' : {
#                 help    : 'Insert Matrix',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\left[\\begin{matrix}  \\end{matrix}\\right]');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-20});
#                 }
#             },
#         'Alt-0' : {
#                 help    : 'Insert partial',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\partial ');
#                 }
#             },
#         'Ctrl-Alt-n' : {
#                 help    : 'Insert nabla',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\nabla');
#                 }
#             },
#         'Alt-Shift-t' : {
#                 help    : 'Insert text',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\text{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
# /*        'Shift-6' : {
#                 help    : 'Insert superscript',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('^{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
#         'Shift-_' : {
#                 help    : 'Insert subscript',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('_{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
# */
#         };
#
#    // var load_ipython_extension = function() {
#         IPython.keyboard_manager.edit_shortcuts.add_shortcuts(add_edit_shortcuts);
#         IPython.keyboard_manager.command_shortcuts.add_shortcuts(add_command_shortcuts);
#     //};

# %% [markdown]
# # Lecture 1

# %% [markdown]
# ## Introduction

# %% [markdown]
# DSP-related application. Radar. Whether this re is a target. They send some pulses; Sonar. we want to localize where the submarine is. To find the bearing, we deploy hydorophones along the surface of the sea. the output will be shifted depending on the distance. We could listen to the propeller of the submarine. EKG; determining the heart rate. There are types of multimedia. Speech, audio, imaging. Applications can be diverse in communications, economics, reliability.   Cell phone, multipath effects. When we have a receiver, reception can happen from reflection of nearby objects.
#
# What is an estimator? it is a function  $g$ of random data. $x[n]$ is random data.
#
# $$ \hat{\theta} = g\left( x[0], x[1], ... ,x[N-1] \right) $$
#
# If there is nothing random, there is no estimation. There are things I don't know; are these things random or deterministic?
#
# Parameter vs waveform estimation. Parameter estimation pertains to a parameter $\theta$ whose dimension is fixed and does not depend on $N$. Waveform estimation depends on the number of elements collected. We will talk about both.
#
# * Estimate - value returned by an estimator
# * Estimator - function $g$ which returns an estimate
# * Estimation - process of figuring out the estimator
#
# We need to clarify how the randomness manifests itself.
#
# $$ p(x[0]; \theta) = \dfrac{1}{\sqrt{2\pi \sigma^2}} e^{-\dfrac{1}{2\sigma^2} \left( x[0] - \theta \right)^2} ~N(\theta,\sigma^2) $$
#
# In other cases, without the probability density funciton ,we have a generator model. This is the data which generates it. We can try to fit a straight line:
#
# $$ x[n] = \theta_t + \theta_2 n +w[n] $$
#
# Where $w[n] ~ N(0,\sigma^2)$. The mean of $x$ is given by $\theta_{1,2}$. we can multiply and figure out from the model:
#
# $$ p(x;\theta) = \dfrac{1}{\sqrt{2\pi \sigma^2}} e^{-\dfrac{1}{2\sigma^2} \sum_{n=1}^{N-1} \left(x[n] - \theta_1 - \theta_2n \right)^2} $$
#
# Parameters are viewed as random (Bayes framework) $p(x,\theta) = p(x|\theta)p(\theta)$ or deterministic $p(x;\theta)$. Pay attention  to something! The semicolon indicates that $\theta$ is deterministic; the comma shows that it is random. We will show it to capture a probability function. If someone tells us that $\theta$ falls within a range, it may be better to use a probability density function within the range.

# %% [markdown]
# ## How good is an estimator

# %% [markdown]
# The major part of this class. Ex:
#
# $$ x[n] = A + w[n] $$
#
# 1. Estimator 1: $ \hat{A} = \dfrac{1}{N} \sum_{n=0}^{N-1} x[n] $
# 2. Estimator 2: $\hat{A} = x[0]$.
#
# If the samples are independent, finding a distribution is easy; however, if the samples are correlated, it is hard. Central Limit Thm (any PDF will converge to a gaussian). and Law of large numbers (take lots of samples). If we know the moments of a variable, we can get the pdf. Moment generating transform, Fourier transform is the PDF. The reason I told you this is that in general, the moments are easy to find. Why is it easy to find?
#
# if $w[n]$ is uncorrelated with zero-mean and variance $\sigma^2$, then:
#
# 1. Estimator 1: $E\left[ \hat{A} \right] = A, $ var$(\hat{A}) = \dfrac{\sigma^2}{N}$
# 2. Estimator 2: $E\left[ \hat{A} \right] = A, $ var$(\hat{A}) = \sigma^2$
#
# Here, we see that the variance is larger for the second estimator, but it is simpler.
#
# Big picture:
#
# 1. parameter $\theta$. Think of a pdf that governs data.
# 2. Using this data, we form an estimator $\hat{\theta}$.
# 3. This gives you an estimate $\hat{\theta}(x)$
#
# Upper case Bold face letters denote matricies. lower case bold letters denote column vectors.

# %% [markdown]
# ## Chapter 2 Minimum-variance unbiased Estimation

# %% [markdown]
# Deterministic $\theta$: Bias $b(\theta) := E\left[ \hat{\theta} \right] - \theta$. Unbiased is : $E\left[ \hat{\theta} = \theta \forall \theta \right]$
#
# Example 1:
#
# $$ x[n] = A+ w[n] $$
#
# 1. $\hat{A} = \dfrac{1}{N} \sum_{n=0}^{N-1} x[n] \implies E\left( \hat{A} \right) = A$
# 2. $\hat{A} = \dfrac{1}{2N} \sum_{n=0}^{N-1} x[n] \implies E\left( \dfrac{1}{2}\hat{A} \right) = A \begin{cases} = A, \text{ if } A=0\\ \neq A, \text{ if } A=0 \end{cases}$
#
# It may be a good idea, to ahve several estimators, if they are uncorrelated. If we combin estimator,s we can maintain biases. We can reduce the variance.
#
# $$ \hat{\theta} = \dfrac{1}{n} \sum_{i=1}^n \hat{\theta}_i $$
#
# Reasonable performance metric? The mean square error has a bias term in it.
#
# $$ mse(\hat{\theta}) = E\left[ \hat{\theta} - \theta \right]^2 =\text{var}(\hat{\theta}) + b^2(\theta) $$
#
# MSE estimators may not be realizable. In a random variable
#
# Biased estimator and unbiased estimator. Unbiasedness may depend on the parameter itself. If we claim it is biased or not biased. The mean is parameter dependent.
#
# Consider an estimator such that the mean squared error is minimized.
#
# $$ mse(\hat{A}) = \dfrac{\alpha^2 \sigma^2}{N} + \left( \alpha-1 \right)^2 A^2 $$
#
# We find that the optimum alpha is dependent on the known parameter A. Do this by setting derivative of MSE=0, and solve for parameter $\alpha$.
#
# $$ \dfrac{\partial MSE}{\partial \alpha} = 0 $$
# $$ \alpha_{opt} = \dfrac{A^2}{A^2 + \sigma^2/N} $$
#
# It needs to minimize the variance of the estimator. What we want to understand is that if we try to combine vias andvariance, your may be unrealizable.
#
# Questipon: Does MVUE (Minimum variance unbiased estimation) always exist? Not in general
# Question: Can we always find it? Not in general.
# MVUEs may not exist.
#
# The dependence on the value of the estimator depends on the value itself. It may be impossible to find an unbiased estimator.
#
# If an MVUE esists, the Cramer-Rao lower bound will tell you what it exists.
# Rao-Blackwell-Lehmann-Scheffe Thm on sufficient statistics will allow us to identify MVUE.
# If all else fails, restrict the estimators to be linear.
#
# Let's finish with a counter-example. Let's look at a pathological problem. $x$ is drawn from a uniform distribuation $U[0,1/\theta]$. We are given just one point of data, which is drawn from a uniform distribution:
#
# $$ \hat{\theta} = g(x[0]) \implies b(\theta) = e\left[ \hat{\theta} \right] - \theta = \theta \int _0^{1/\theta} g(u) du = = $$
#
# Because the distribution is uniform, it intigrates to 0. Let's look at this calculation a little more closely:
#
# $$ E\left[ \theta \right] = \int \hat{\theta} P_{\hat{\theta}}(\hat{\theta}) d\hat{\theta} $$
# $$ = \int g\left( x[0] \right) $$
#
# Because it is a uniform distribution, the funciton is essentially a step function; thus our sample is essentially a dummy variable.
#
# Back to the main derivation:
#
# $$  $$
#
# $$ \implies \int_0^{1/\theta} g(u) du = 1 $$
#
# This is important. Thre does not exits some function $g$ to satisfy the baove equation for $\forall \theta > 0$ because $\forall g(x) > 0$, the itegral maybe 1 for some $\theta$, but not $\forall \theta$.
#
# Not even a single unibased estimator exists here. Wow.

# %% [markdown]
# Wed 1/17 5:30 402, 404, 405 (Walter Library)

# %% [markdown]
#  # Lecture 4 - 1-18-2017

# %% [markdown]
# We motivated the cramer lowe bound. The dependenceo f the data on the pdf. The variance islower bounded by 1/the expected vurvature. If we stop there, we basically have a benchmark. If we stop the thm there, among all unbiased estimators, we cannot dobetter than this. If we can factorize the denominator, where the function of x is the lower part of $\theta$. If this is the case, two things can be reduced.  Best variance is $1/I(\theta)$. There is another thing to stress. I called efficient estimator that attains the bound. It is conceivible. The bound may be even lower. Efficient is unbiased and acheiving the lower bound. This is the best we can think. If the condition is not satisfied, or rather if we cannot factor this, then we cannot identify the MVUE from it. this means that the MVUE can never be factorized. Clearly, there is a distinction between this and the estimator.
#
# Efficient is unbiased achieving CRLB. This is not nevessairly the same as MVUE. If we can find MVUE from the bound, the two coincide.
#
# <img src=''>
#
# Then we said:
# $$ \dfrac{\partial \ln (p(x))}{\partial \theta} = \dfrac{1}{C(\theta)} $$
#
# not a function of $x$. We provided the proof. We gave example. One example was the mean. The MVUE may not obtain the bound. To make this more solid, we indivted that efficient and MVUE is not the same.
#
# We made a comment about frequency estimation. Some $f_0$s are easier to estimate than others. If we know how to estimate a certain variable, how about functions of these parameters? If we havea $\hat{\theta}$ which is efficient, then any affine transform is also efficient. The story is different with nonlinear estimators. We can only estimate those if we have limiting data lengths.
#
# Let's try to translate the scalars to the vector case:
# $$ \theta:= \left[\begin{matrix} \theta_1,& ...,& \theta_p \end{matrix}\right] $$
#
# If we havethe covarience matrix for any unbiased estimator, the covariance is greater than:
# $$ C_\theta := E\left[ (\hat{\theta} - \theta)(\hat{\theta} - \theta^T) \right] \geq I^{-1}(\theta) $$
#
# The information is derivable with the derivable vound. It is done in the derivative of the logarithm which makes the gradient. If the vovarience matrix is the same as before. Some things to check the unbiasedness, a well-done condition. This implies that tif we takethe exptected value on both side of the equation, because this is 0, we can immediately dedcue that the estimator is unbiased.
#
# What is meant by the positive definiteness? This relates not only to. We we want todraw a conclusion to entry number 3 of the estimator matrix, then we must multiply by the indicator matrix (0s everywhere except 1 where we want it). From this we draw conclusion of thevariances on the individual entries of $\theta$.
#
# Take for example, as $\theta$ being:
#
# $$ \theta = \left[\begin{matrix} \theta_1 \\ \theta_2 \end{matrix}\right] \implies \left[ CRLB(\theta) \right] \geq \left[ I^{-1}(\theta) \right] $$
#
# The Fisher matrix is not necessairly diagonal. The off diagonal entries tell you how the cross correlators are related. The
#
# $$  C_{\hat{\theta}}= \left[\begin{matrix} cov(\hat{\theta}_1, \hat{\theta}_2\\ same here \end{matrix}\right] $$
#
# Thisis ensured in linear models. If we have a linear model of the form:
#
# $$ x = H\theta+ w $$
#
# and suppose $w ~ N(0,\sigma^2I)$. Because this i snormal, the data is also distributed according to $x ~ N(H\theta,\sigma^2I)$. Let's look at the log of the pdf.
#
# $$ \dfrac{\partial \ln}{\partial \theta} = L(\theta) \left[ (H^T H)^{-1} x - \theta \right] $$
#
# In one particular example which obeys the linear model. It is useful. This relates to curve fitting. Suppsoe we have a straight line curve fitting. Thisis something to do, curve fitting, in least squares. Here, we will see that if the noise approximation narrows are Gaussian and zero mean, then if we plug the Fisher matrix into it.
#
# If we differentiante w.r.t. B, we get another term on theend. If we start differentiating w.r.t. A, then X9n) gets killed.
#
# It is easier to estimate the things which change faster. Ex. it is easier to estimate the quadratic coefficient than the slope.
#
# If the B were known. For a problem If we compare the $\sigma^2/N$ to the variance of A, the bound is larger than when we have another parameter. You may say, for example, you should use 2-3 parameters.
#
# If $\hat{\theta}$ is efficient, then any affine transform is efficient. This is only true for $N \to \infty$.
#
# The most general case we can think of, the mean andcovariance to depend on some parameter.
#
# Start with x and $\theta$. If the expoentn, we have a quadratic form. We kick out th eexpoenential, bring it down, then differentiate w.r.t. $\theta_k$, then differentiate the second part. We can just use this fact then the thm is proved.
#
# We would rather have another example. Once more we have a situation where A is a known, but it is not a deterministic unknown, but rather a random unknown from a random distrubtion with an unknown variance. Find the CRLB for the knwon variance.
#
# If we have amatrix of sum of matrices, then we can express it as the inversion of individual matrices in a special equation (woodbury's inversion Lemma). If the BCD is $uu^T$In a matrix, if we add, we can invert them efficiently. We understand that a matrix with the SVD, if it grows in singular values, then it adds. If I know how to update, we are in good shape.
#
# Range estimation. In range estimation, we try to find the distance to rarget. The signal $s(t)$. We are receiving the signal dith a delay and in the presence of noise. The problem statement is to recognize, if we have aspeed $c$, then $\tau_0 = 2R/c$. Sample the continuous waveform at the nyquist rate (n/2B). The noise is bandlimited. Is white noise a realistic model? No, no bandwidth. After passing through a bandwidth filter, it has no longer a uniform spectrum. By samplint at nyquist, we sample in the valleys of the new, modified specturm. Very clever!
