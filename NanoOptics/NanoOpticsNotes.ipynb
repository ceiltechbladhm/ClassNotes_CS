# %% [markdown]
# # Commands

# %%
# %%javascript
#
#     var add_command_shortcuts = {
#             'Alt-w' : {
#                 help    : 'Add Text Test',
#                 help_index : 'aa',
#                 handler : function() {
#                         var cell = IPython.notebook.get_selected_cell();
#         		cell.code_mirror.replaceSelection('Testing');
#                 }
#             }
#         };
#
#     var add_edit_shortcuts = {
#             'Alt-a' : {
#                 help    : 'Insert alpha',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\alpha');
#                 }
#             },
#         'Alt-b' : {
#                 help    : 'Insert beta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\beta');
#                 }
#             },
#         'Alt-g' : {
#                 help    : 'Insert gamma',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\gamma');
#                 }
#             },
#         'Alt-shift-g' : {
#                 help    : 'Insert Gamma',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\Gamma');
#                 }
#             },
#         'Alt-Ctrl-d' : { //Change
#                 help    : 'Insert delta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\delta');
#                 }
#             },
#         'Alt-Ctrl-e' : {
#                 help    : 'Insert epsilon',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\epsilon');
#                 }
#             },
#         'Alt-z' : {
#                 help    : 'Insert zeta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\zeta');
#                 }
#             },
#         'Alt-t' : {
#                 help    : 'Insert theta',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\theta');
#                 }
#             },
#         'Alt-k' : {
#                 help    : 'Insert kappa',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\kappa');
#                 }
#             },
#         'Alt-l' : {
#                 help    : 'Insert lambda',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\lambda');
#                 }
#             },
#         'Alt-p' : {
#                 help    : 'Insert phi',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\phi');
#                 }
#             },
#         'Alt-r' : {
#                 help    : 'Insert rho',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\rho');
#                 }
#             },
#         'Alt-s' : {
#                 help    : 'Insert sigma',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\sigma');
#                 }
#             },
#         'Alt-w' : {
#                 help    : 'Insert omega',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\omega');
#                 }
#             },
#         'Ctrl-Alt-1' : {
#                 help    : 'Insert dfrac',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\dfrac{}{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-3});
#                 }
#             },
#         'Ctrl-Alt-7' : {
#                 help    : 'Insert integral',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\int_{}^{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-4});
#                 }
#             },
#         'Ctrl-Alt-3' : {
#                 help    : 'Insert cos',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\text{cos}');
#                 }
#             },
#         'Ctrl-Alt-4' : {
#                 help    : 'Insert sin',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\text{sin}');
#                 }
#             },
#         'Ctrl-Alt-5' : {
#                 help    : 'Insert Brackets',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\left[  \\right]');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-8});
#                 }
#             },
#         'Ctrl-Alt-6' : {
#                 help    : 'Insert parenthesis',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\left(  \\right)');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-8});
#                 }
#             },
#         'Ctrl-Alt-7' : {
#                 help    : 'Insert parenthesis',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\left[\\begin{matrix}  \\end{matrix}\\right]');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-20});
#                 }
#             },
#         'Ctrl-Alt-2' : {
#                 help    : 'Insert equation',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('$$  $$');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-3});
#                 }
#             },
#         'Alt-0' : {
#                 help    : 'Insert partial',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\partial ');
#                 }
#             },
#         'Ctrl-Alt-n' : {
#                 help    : 'Insert nabla',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\nabla');
#                 }
#             },
#         'Alt-Shift-t' : {
#                 help    : 'Insert text',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('\\text{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
# /*        'Shift-6' : {
#                 help    : 'Insert superscript',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('^{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
#         'Shift-_' : {
#                 help    : 'Insert subscript',
#                 help_index : 'aa',
#                 handler : function() {
#                     var cell = IPython.notebook.get_selected_cell();
#                     cell.code_mirror.replaceSelection('_{}');
#                     var cpos = cell.code_mirror.getCursor();
#                     cell.code_mirror.setCursor({line: cpos.line, ch: cpos.ch-1});
#                 }
#             },
# */
#         };
#
#    // var load_ipython_extension = function() {
#         IPython.keyboard_manager.edit_shortcuts.add_shortcuts(add_edit_shortcuts);
#         IPython.keyboard_manager.command_shortcuts.add_shortcuts(add_command_shortcuts);
#     //};

# %% [markdown]
# # Lecture 1

# %% [markdown]
# Study optics at the nano scale. There are practical applications.
#
# Examples from nano optics too.
#
# EE 5-119
# sang@umn.edu
# http://nanobio.umn.edu
# Sang-Hyun Oh
#
# No books, however some good references
# Book: Stefan Mair Plasmonics
# Book: Heinz Raether, Surface Plasmons
# Book: S. Kawata, Near-field optics and surface pasmon polaritions
#
# Lumierical solver can be downloaded with a 1-month trial license
#  - to model optical effects
#
# 60% Homework
# 20% Final Project
# 20% Final report
#
# Understanding key concepts in nano-optics: surface plasmon resonance, near-field imaging, optical biosensing, plasmon-emitter coupling, surface-enhanced spectroscopy
#
# Review of EM and optics in the contexts of plasmonics
# In-depth study of one topic of your choice

# %% [markdown]
# We study a Surface Plasmon Wave
#
# This wave is bound and progagates along a metallic surface. There is a special mode which can propagate along the metal. What we do is define a very small groove on the surface. The groove is many times smaller than the wavelength. A spherical wave emerges.
#
# E&M is used to model these events. Nevertheless, one can make a negative index of refraction, squeezing light into a structure more than 1000x smaller than the wavelength.
#
# Extraordinary optical transmission effect discovered by Thomas Ebbesen. launched a new field.
#
# Plasmonics primairly concerns metallic nanostructures. Nanostructures are requred. Focused Ion Beam (FIB) required to make it (or also an e-beam).
#
# We can use other emerging tools, such as near field microscopes.
#
# Get some experience in the clean room.
#
# Extraordinary Optical Transmission. Originally then wanted to study what happened within nanoscale holes. When they shined light through the holes, the transmission of a certain wavelength becomes much stronger than what is predicted by conventional theory. When you shine a plane wave onto the metal fillaments. There is some sort of resonance between the light and electrons. There is a very strong field within the hold. It acts as a very strong resonator.
#
# After we learn some basic theories, we can start to use FDTD solutions to model plasmonics. We can invent our own nano structures.
#
# The promise of plasmonics:  optical frequency but nanoscalee wavelengths. Path for miniaturzation of photonics devices. Integration of photonics and electonics.
#
# Stained glass workers knew that putting gold and silver and small amounts into the glass will add some color. Electrons will oscillate with the light, scattering and absorbing certain wavelengths. IN the same way, nanoparticles are added to change material properties.
#
# A few applications: a comercialized application before 1980s created by physicists. Biacore. Surface plasmon resonance used to detect molecular binding. Protiens will bind onto the film; the pathway is very sensitive to these bindings.
#
# Near-field scanning Optical Microscopy. A metal tip is scanned over a surface. A laser is shone on the tip.
#
# Pregnancy Test Kit too???
#
# Surface-enhanced Spectroscopy
#
# Raman spectroscopy. IN the spectral domain, different peaks have different frequencies for different molecules.
#
# Heat-assisted magnetic recording. HAMR. Basically, bits are so small, it is easy to flip them. Heat helps to create a "magnetically hard" material.
#
# Surface Plasmons in Grpahene
# 2D materials support surface plasmon waves. Novel applications in sensint, spectroscopy.

# %% [markdown]
# # Lecture 2 Electrodynamics of Metals

# %% [markdown]
# Locally around metallic structure, an electric field will be generated.
#
# How to model metals physically.
#
# Reading is Chapter 1 from Maier's textbook.
#
# We will focus on metals. Aluminum is abundant and relatively cheap. It was the original metal. Now days it is copper. Both very cheap and conductive. Both can sustain plasmons. Most widely used metals in nanooptics are silver and gold. Platinum, there is no particular reason to use them in nanooptics. Usually more expensive than gold. Tungsten can be used in microelectrodes. Optical properties in visible wavelength are not very good. Can be used in IR range.
#
# $$ \nabla \cdot D = \rho_{Ext} $$
# $$ \nabla \cdot B = 0 $$
# $$ \nabla \times E = - \dfrac{\partial B}{\partial t} $$
# $$ \nabla \times H = \dfrac{\partial D}{\partial t} + J $$
#
# Have a material (say sphere made with gold), there are free electrons. Exterally applied field causes polarization.
#
# $$ D = \epsilon_oE + P(E) = \epsilon_o\epsilon E $$
#
# When the polarization P varies from place to place, there is a charge density given by
# $$ \rho_{pol} = -\nabla \cdot P $$
#
#
#
# We will ignore magnetic effects typically. There are some groups looking at how to apply this magnetic technology.

# %% [markdown]
# Historical notes on E, D , B, H.
#
# At certain frequencies, $D = \epsilon_o \epsilon E$, the $\epsilon=0$. The electrons, in the absence of an external electric charge, the electrons will cancel out??? In some cases, we can have oscillations which has Electirc field, but no D field. The electric field and polarization field cancel out. We must be careful between physical meanings between D and E fields.
#
# Everything is a summary of Maxwells equations.
#
# General Form of Dielectric Function.
#
# $$ D(k,\omega) = \epsilon(k, \omega) E(K,\omega) $$
#
# Some examples. When things are really small, (cavity or gap in metal smaller than wavelength). There are exampls on when we need to get this spatially dependent effect. The simple dieletric function cannot describe physics when things get super small).
#
#
# Goal: understand statement: Longitudinal ossilations can only occur at zeros of $\epsilon(\omega)$.
#
# start with two curl equations
#
# $$ \nabla \times E = \dfrac{\partial B}\partial t{} $$
# $$ \nabla \times H = \dfrac{\partial D}{\partial t} + J $$
#
# for $E(r) = E_0 e^{i(k\cdot r - \omega t)}$
#
# For plane waves, divergence $\nabla \cdot E = iK \cdot D$
# $\nabla \times E = i K \times E$
#
# $$ \nabla(\nabla \cdot E) - \nabla^2E = -K(K\cdot E ) + K^2E $$
# $$ =\mu_0 \epsilon(K,\omega)\omega^2 E  $$
#
# Master equation:
# $$ K(K\cdot E) - K^2 E = -\epsilon(K,\omega)\dfrac{\omega^2}{c^2}E $$
#
# For transverse waves, $K \cdot E = 0$, $K^2 = \epsilon(K,\omega)\dfrac{\omega^2}{c^2}$
#
# $$ \omega^2 = \dfrac{1}{\epsilon}c^2 K^2 $$
# $$ \omega = \dfrac{1}{\sqrt{\epsilon}}cK $$
#
# For longitudinal waves,
#
# $$ K(K\cdot E ) - K^2 E = 0 $$
#
# Therefore, $\epsilon(K,\omega) = 0$
#
# Physically, the zero delectric means.

# %% [markdown]
# Electrons move back and forth through the metal sphere, which generates a changing electric field. We assume continuous, not discrete electrons. Extreme scale, nanoparticles

# %% [markdown]
# Dielectric function of free electron Gas. Basically equation for harmonic oscillator.
#
# $$ m\ddot{x} + m\gamma \dot{x} = -eE $$
#
# Aply exteral electric field. This is a dampening. The dampening constant is the $\gamma$. Assume damping is proportional to velocity. We will assume harmonic
#
# $$ \vec{x} = \vec{x_o}e^{i\omega t} $$
# $$ \vec{E} = \vec{E_o}e^{i\omega t} $$
#
# $$ -\omega^2 m \vec{x} - i\omega mr\vec{x} = -e\vec{E} $$
#
# $$ (m\omega^2 + mr\omega) \vec{x} = e\vec{E}$$
#
# We then get the equation of motion.
#
# $$ x(t) = \dfrac{e E(t)}{m(\omega^2 + i\gamma \omega)} $$
#
# This is frequency dependent. When electrons move around, it creates a polarization vector. Defined as displacement times amount of charge.
#
# $$ P = -nex = -\dfrac{ne^2 E}{m(\omega^2 + i\gamma \omega} $$ (macroscopic polarization)
#
# $$ D = \epsilon_o E + P = \epsilon_o(1 - \dfrac{ne^2}{\epsilon_om(\omega^2 + i \gamma \omega)})E =  $$
#
# define $\omega_p = \sqrt{\dfrac{ne^2}{\epsilon_o m}}$ as plasma frequency. This is important that $\omega_p \propto \sqrt{n}$
#
# The dielectric function is therefore defined as
#
# $$ \epsilon(\omega) = 1-\dfrac{\omega_p^2}{\omega^2 + i\gamma \omega} $$
#
# The doped silicon has a lower n; therefore the frequency is also lower. Makes it harder to use for visible range.
#
# The background atoms have some bound charges; we must add those later. This is the simplest model however.

# %% [markdown]
# ** The Dielectric Function**
#
# $$ \epsilon(\omega) = 1-\dfrac{\omega_p^2}{\omega^2 + i\gamma \omega} = \epsilon_1(\omega) + i_2(\omega) $$
#
# For most metals, $\tau = \dfrac{1}{\gamma} \approx 10$ femptoseconds for most metals. IN metals, when electrons move around, dampenings can occur from many thins. We approximate it as nothing. this makes the Non-lossy Drude model:
#
# $$ \epsilon(\omega) = 1-\dfrac{\omega_p^2}{\omega^2} $$
#
# The
# In some textbooks, instead of a dielectric function, we can see $n(\omega) = \sqrt{\epsilon} = n(\omega) + i\kappa(\omega)$. Here, n is the refractive index. For the most part, we will use dielectric function. Possible to convert between these two definitions.
#
# Typical values for dampening. Typical relaxation time ($\tau$). is ~10fs. The frequency is near ultraviolet.
#
# Optical properties of various metals. Epsilon is called permittivity. When metals at typical operating frequencies. Metals have a negative permittivity. As a function of wavelength, the absolute value of real part becomes a large negative number. The nagative Re[$\epsilon(\omega)$] is the origin of plasmonic effects. Metals must repel electric field. We also have imaginary part of $\epsilon$. This is the source of optical loss (the dampening).
#
# There are some peaks due to other poperties; however generally a monotonous relationship. Gid difference betwen fold and silver, above wavelenth 600 nm is very similar. Below, however, optical loss of gold increases rapidly, whereas silver is still usable. Just remember, beyond 600 nm, gold silver and copper have similar properties. Below 600, silver is the best (but tarnishes easily).
#
# If we plot based on the Drude Model, we get some large differences between the model and the measured data. There is a large peak in absorption. This is due to the transition bands. There is a sufficiently high energy. Interband transitions are only one discrepancy. There are other effects, such as nonlocality.
#
# Dispersion of free electron gas.
#
# what happens in metal assuming electon gas, and light is propagating in medium. Different that vaccuum or dielectric material. Mor transverse wave, the general rlationship K is given by: $K^2 = \epsilon(K,\omega)\dfrac{\omega^2}{c^2}$. For metals, we have aspecific metal.
#
# From this, we can get: $\omega^2 = \omega_p^2 + K^2c^2$. Plotting this will give us what happens. . In free space, $\omega = ck$, and the plot of dispersion is simply a straight line.
#
# If medium has no loss, at high frequency, positive index of refraction. High frequency wave, metals will be transparent. Below this frequency, metals become a mirror. If we shine high enough frequency light, it simply passes through metal. For low frequency light, gets reflected.
#
# Big concept: metals become transparent above plasma frequency. Plasma frequency is when $\epsilon=0$

# %% [markdown]
# # Lecture 4

# %% [markdown]
# Let's look at the meaning of the formula.  Physically, this has a significant impact on light. Plasma is pasically a collection of positive and negative charges. When $\omega < \omega_p$, it is negative. Above, plasma frequency, $\epsilon $ is positive.  At $\omega>\omega_p$, transmission of light occurs.
#
# Some examples of $\omega_p$ are in the notes.
#
# The exponential decay we see in metal is known as evanescant decay. The real and imaginary part of $\epsilon$
#
# $$ \epsilon_1 = n^2 - k^2 $$
# $$ n(\omega) = \sqrt{\epsilon} $$
# $$ e-2 = 2nk $$
# $$ k = \dfrac{\epsilon_2}{2n} $$
# $$ \epsilon = \epsilon_1 + i\epsilon_2 $$
#
# $$ E_0 e^{iKx - \omega t} = E_0 e^{-\dfrac{\omega}{c}kx + i(\dfrac{\omega}{c}nx - \omega t)} $$
#
# ONe terminology: PEC (perfect electrical conductor). Different that superconductor. Lossless conductor. WE assume metal is lossless. Different than perfect conductor. There is no electrical field in side the metals (in real world there is, but we assume not). Then the metal behaves like a perfect conductor.
#
# We defined $\omega_p$, below which the metals behave very differently. The same concept applies to any conductive medium (such as the ionosphere).
#
# Let's look at displacement vector:
# $$ D - \epsilon_o \epsilon(\omega_p)E = 0 $$
#
# The E-feild can exist withoug the D-field. What does this mean? Here, $\epsilon=0$. The situation we are looking at is an infinitely wide sheet of metal. A very small displacement of electron gas, $u$ is undergone. Suppose we displace all the electrons by the same amount.
#
# $$ \sigma = \pm neu $$
#
# $\sigma$ is the amount of charge per unit area.
#
# The positive charges will remain the same; when electrons are displaced up, the bottom shows positive charge. The top becomes negatively charged. This becomes something of a capacitor. To describe the motion, we must look at the electrons as particles themselves. Equation of motion: $F = ma$. Here, $a$ is the second derivative of the physical displacement $u$. $n$ is the number of electrons per unit volume.
#
# $$ nm\ddot{u} = -neE =  $$
#
# Let's apply Gauss's law to the "capacitor". The field outside is 0.
#
# $$ \int E \cdot da = \dfrac{Q}{\epsilon_o} $$
# $$ EA = \dfrac{-\sigma A}{\epsilon_o} $$
# $$ E = \dfrac{\sigma}{\epsilon_o} $$
# $$ = -ne\dfrac{neu}{\epsilon_o} $$
# $$ -\dfrac{n^2e^2u}{\epsilon_o} $$
# $$ m\ddot{u} = -\dfrac{ne^2}{\epsilon_o}u $$
#
# Also note, from spring model basic physics:
#
# $$ m\ddot{u} = -ku $$
#
# Recall
#
# $$ \omega_p = \sqrt{\dfrac{ne^2}{\epsilon_o m}} $$
#
# $$ \ddot{u} = \omega^2_p u = 0 $$

# %% [markdown]
# ## Fresnels Equation for a 5 Layer Stack

# %% [markdown]
# Surface plasmon resonance.
#
# When proteins bond to the surface of gold, the change of index of refraction caused by the proteins changes the polarization angle of the light at which surface plasmon resonance occurs.
#
# We would have a Dielectric Brag mirror. We will develop simple code to calculate the effect. We want to simulate surface plasmom resonance.
#
# Snells law: if we have transparent dielectric material:
#
# $$ n_1 \sin \theta_1  = n_2 \sin \theta_2 = n_2 \sin \theta_3 = ... $$
#
# We change to a cos because it becomes more convenient later on. Derived from $\cos^2 + \sin^2 = 1$
#
# $$ \cos \theta_i = \sqrt{1 - \left( \dfrac{n_1}{n_i} \right)^2 \sin^2\theta_1} $$
#
#
#
# Fresnel Equations
